# %%
vid_path='v_YoYo_g01_c04.mp4'

# %%
from IPython.display import Video
Video(vid_path,embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !pip install pixellib
# Out:
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
# Collecting hydra-core
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: future in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (0.18.2)
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20220512.tar.gz (50 kB)
# Requirement already satisfied: cloudpickle in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (2.0.0)
# Requirement already satisfied: pyQt5 in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (5.15.6)
# Requirement already satisfied: tqdm in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (4.62.3)
# Requirement already satisfied: black in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (19.10b0)
# Requirement already satisfied: matplotlib in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (3.5.0)
# Requirement already satisfied: scikit-image in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (0.18.3)
# Requirement already satisfied: imgaug in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (0.4.0)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: opencv-python in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (4.5.5.62)
# Requirement already satisfied: termcolor in c:\users\~khadija bn\appdata\roaming\python\python38\site-packages (from pixellib) (1.1.0)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: Cython in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (0.29.25)
# Collecting omegaconf
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting iopath
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Requirement already satisfied: pillow in c:\users\khadija bn\anaconda3\lib\site-packages (from pixellib) (8.4.0)
# Requirement already satisfied: toml>=0.9.4 in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (0.10.2)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (1.4.3)
# Requirement already satisfied: click>=6.5 in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (8.0.3)
# Requirement already satisfied: regex in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (2021.8.3)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (0.7.0)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (21.4.0)
# Requirement already satisfied: appdirs in c:\users\khadija bn\anaconda3\lib\site-packages (from black->pixellib) (1.4.4)
# Requirement already satisfied: colorama in c:\users\khadija bn\anaconda3\lib\site-packages (from click>=6.5->black->pixellib) (0.4.4)
# Requirement already satisfied: numpy in c:\users\khadija bn\anaconda3\lib\site-packages (from fvcore->pixellib) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\khadija bn\anaconda3\lib\site-packages (from fvcore->pixellib) (6.0)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: packaging in c:\users\khadija bn\anaconda3\lib\site-packages (from hydra-core->pixellib) (21.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: lxml in c:\users\khadija bn\anaconda3\lib\site-packages (from imantics->pixellib) (4.7.1)
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: Shapely in c:\users\khadija bn\anaconda3\lib\site-packages (from imgaug->pixellib) (1.8.0)
# Requirement already satisfied: imageio in c:\users\khadija bn\anaconda3\lib\site-packages (from imgaug->pixellib) (2.9.0)
# Requirement already satisfied: scipy in c:\users\khadija bn\anaconda3\lib\site-packages (from imgaug->pixellib) (1.4.1)
# Requirement already satisfied: six in c:\users\khadija bn\anaconda3\lib\site-packages (from imgaug->pixellib) (1.16.0)
# Requirement already satisfied: networkx>=2.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from scikit-image->pixellib) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\khadija bn\anaconda3\lib\site-packages (from scikit-image->pixellib) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\khadija bn\anaconda3\lib\site-packages (from scikit-image->pixellib) (1.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\khadija bn\anaconda3\lib\site-packages (from matplotlib->pixellib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\khadija bn\anaconda3\lib\site-packages (from matplotlib->pixellib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from matplotlib->pixellib) (4.28.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khadija bn\anaconda3\lib\site-packages (from matplotlib->pixellib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\khadija bn\anaconda3\lib\site-packages (from matplotlib->pixellib) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from importlib-resources->hydra-core->pixellib) (3.7.0)
# Collecting sahi>=0.8.19
#   Downloading sahi-0.9.4-py3-none-any.whl (81 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from labelme2coco->pixellib) (3.2.0)
# Requirement already satisfied: setuptools in c:\users\khadija bn\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.18.0)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Requirement already satisfied: requests in c:\users\khadija bn\anaconda3\lib\site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.27.1)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting click>=6.5
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\khadija bn\anaconda3\lib\site-packages (from portalocker->iopath->pixellib) (302)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\khadija bn\anaconda3\lib\site-packages (from pyQt5->pixellib) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\khadija bn\anaconda3\lib\site-packages (from pyQt5->pixellib) (12.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\khadija bn\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khadija bn\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khadija bn\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\khadija bn\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.0.4)
# Building wheels for collected packages: fvcore, antlr4-python3-runtime, imantics, fire
#   Building wheel for fvcore (setup.py): started
#   Building wheel for fvcore (setup.py): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220512-py3-none-any.whl size=61288 sha256=8a5f5dc38d7439fea3f0ef838a1af125450278e9dcbcd1c4f243d57d32fad030
#   Stored in directory: c:\users\~khadija bn\appdata\local\pip\cache\wheels\bc\f4\d9\8b3c3f254c28aa2daf5e2f5a8070b0a960278733fd2eb1f7a2
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=65a28ed4ba78b69d4a2a71082cbdd45d399c37e0c1a8c8a30d41fe69751ff89f
#   Stored in directory: c:\users\~khadija bn\appdata\local\pip\cache\wheels\b1\a3\c2\6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for imantics (setup.py): started
#   Building wheel for imantics (setup.py): finished with status 'done'
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16033 sha256=ecef7dbef1cf1170745e0134f445bf49033430e43fd3c911c405a3a05425d1ea
#   Stored in directory: c:\users\~khadija bn\appdata\local\pip\cache\wheels\3d\a5\ec\e0fe6d18df133bf33ddc4a4148646677f45a24be2732b4ec86
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=e717c3a4cdfb32c6e280034b732335981297094fcd8386e49e419bca9c2cd651
#   Stored in directory: c:\users\~khadija bn\appdata\local\pip\cache\wheels\1f\10\06\2a990ee4d73a8479fe2922445e8a876d38cfbfed052284c6a1
# Successfully built fvcore antlr4-python3-runtime imantics fire
# Installing collected packages: terminaltables, portalocker, fire, click, antlr4-python3-runtime, yacs, xmljson, tabulate, sahi, omegaconf, iopath, importlib-resources, pydot, labelme2coco, imantics, hydra-core, fvcore, dataclasses, pixellib
#   Attempting uninstall: click
#     Found existing installation: click 8.0.3
#     Uninstalling click-8.0.3:
#       Successfully uninstalled click-8.0.3
# Successfully installed antlr4-python3-runtime-4.9.3 click-8.0.4 dataclasses-0.6 fire-0.4.0 fvcore-0.1.5.post20220512 hydra-core-1.2.0 imantics-0.1.12 importlib-resources-5.7.1 iopath-0.1.9 labelme2coco-0.2.1 omegaconf-2.2.2 pixellib-0.7.1 portalocker-2.4.0 pydot-1.4.2 sahi-0.9.4 tabulate-0.8.9 terminaltables-3.1.10 xmljson-0.2.1 yacs-0.1.8

# %%
import pixellib
from pixellib.semantic import semantic_segmentation

# %%
# Creating a semantic_segmentation object
segment_video = semantic_segmentation()
# Loading the Xception model trained on ade20k dataset
segment_video.load_ade20k_model("deeplabv3_xception65_ade20k.h5")
# Processing the video
segment_video.process_video_ade20k(
    vid_path, 
    frames_per_second=100,
    overlay = True,
    output_video_name="semantic_seg_output.mp4",
)
