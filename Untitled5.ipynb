# %%
# !pip install pixellib
# Out:
# Collecting pixellib
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scrapy 2.5.1 requires zope.interface>=4.1.3, which is not installed.
#   Using cached pixellib-0.7.1-py3-none-any.whl (430 kB)
# Requirement already satisfied: tqdm in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (4.62.3)
# Collecting imantics
#   Using cached imantics-0.1.12.tar.gz (13 kB)
# Requirement already satisfied: opencv-python in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (4.5.5.64)
# Requirement already satisfied: termcolor in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (1.1.0)
# Requirement already satisfied: iopath in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (0.1.9)
# Requirement already satisfied: yacs in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (0.1.8)
# Collecting hydra-core
#   Using cached hydra_core-1.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: black in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (19.10b0)
# Requirement already satisfied: Cython in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (0.29.23)
# Collecting imgaug
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Collecting fvcore
#   Using cached fvcore-0.1.5.post20220512.tar.gz (50 kB)
# Requirement already satisfied: future in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (0.18.2)
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (0.8.9)
# Collecting scikit-image
#   Downloading scikit_image-0.19.2-cp37-cp37m-win_amd64.whl (12.5 MB)
# Collecting pyQt5
#   Using cached PyQt5-5.15.6-cp36-abi3-win_amd64.whl (6.7 MB)
# Requirement already satisfied: omegaconf in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (3.1.2)
# Requirement already satisfied: pydot in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (1.4.2)
# Requirement already satisfied: pillow in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (9.0.1)
# Collecting labelme2coco
#   Using cached labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: cloudpickle in c:\users\imane\anaconda3\lib\site-packages (from pixellib) (2.0.0)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (0.7.0)
# Requirement already satisfied: toml>=0.9.4 in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (0.10.2)
# Requirement already satisfied: regex in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (2022.3.15)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (1.4.3)
# Requirement already satisfied: click>=6.5 in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (8.0.4)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (21.2.0)
# Requirement already satisfied: appdirs in c:\users\imane\anaconda3\lib\site-packages (from black->pixellib) (1.4.4)
# Requirement already satisfied: colorama in c:\users\imane\anaconda3\lib\site-packages (from click>=6.5->black->pixellib) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\imane\anaconda3\lib\site-packages (from click>=6.5->black->pixellib) (4.8.1)
# Requirement already satisfied: numpy in c:\users\imane\anaconda3\lib\site-packages (from fvcore->pixellib) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\imane\anaconda3\lib\site-packages (from fvcore->pixellib) (6.0)
# Requirement already satisfied: portalocker in c:\users\imane\anaconda3\lib\site-packages (from iopath->pixellib) (2.4.0)
# Requirement already satisfied: packaging in c:\users\imane\anaconda3\lib\site-packages (from hydra-core->pixellib) (21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\imane\anaconda3\lib\site-packages (from hydra-core->pixellib) (4.9.3)
# Collecting importlib-resources
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Collecting lxml
#   Downloading lxml-4.9.0-cp37-cp37m-win_amd64.whl (3.6 MB)
# Requirement already satisfied: xmljson in c:\users\imane\anaconda3\lib\site-packages (from imantics->pixellib) (0.2.1)
# Requirement already satisfied: imageio in c:\users\imane\anaconda3\lib\site-packages (from imgaug->pixellib) (2.9.0)
# Requirement already satisfied: six in c:\users\imane\anaconda3\lib\site-packages (from imgaug->pixellib) (1.16.0)
# Requirement already satisfied: scipy in c:\users\imane\anaconda3\lib\site-packages (from imgaug->pixellib) (1.7.3)
# Requirement already satisfied: Shapely in c:\users\imane\anaconda3\lib\site-packages (from imgaug->pixellib) (1.8.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\imane\anaconda3\lib\site-packages (from scikit-image->pixellib) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\imane\anaconda3\lib\site-packages (from scikit-image->pixellib) (2021.7.2)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-win_amd64.whl (4.2 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\imane\anaconda3\lib\site-packages (from packaging->hydra-core->pixellib) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\imane\anaconda3\lib\site-packages (from importlib-metadata->click>=6.5->black->pixellib) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\imane\anaconda3\lib\site-packages (from importlib-metadata->click>=6.5->black->pixellib) (3.10.0.2)
# Requirement already satisfied: jsonschema>=2.6.0 in c:\users\imane\anaconda3\lib\site-packages (from labelme2coco->pixellib) (3.2.0)
# Requirement already satisfied: sahi>=0.8.19 in c:\users\imane\anaconda3\lib\site-packages (from labelme2coco->pixellib) (0.9.4)
# Requirement already satisfied: setuptools in c:\users\imane\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (61.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\imane\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.18.0)
# Requirement already satisfied: requests in c:\users\imane\anaconda3\lib\site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.26.0)
# Requirement already satisfied: terminaltables in c:\users\imane\anaconda3\lib\site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (3.1.10)
# Requirement already satisfied: fire in c:\users\imane\anaconda3\lib\site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\imane\anaconda3\lib\site-packages (from matplotlib->pixellib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\imane\anaconda3\lib\site-packages (from matplotlib->pixellib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\imane\anaconda3\lib\site-packages (from matplotlib->pixellib) (2.8.2)
# Requirement already satisfied: pywin32>=226 in c:\users\imane\anaconda3\lib\site-packages (from portalocker->iopath->pixellib) (302)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\imane\anaconda3\lib\site-packages (from pyQt5->pixellib) (12.10.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\imane\anaconda3\lib\site-packages (from pyQt5->pixellib) (5.15.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\imane\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\imane\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imane\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\imane\anaconda3\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (1.26.7)
# Building wheels for collected packages: fvcore, imantics
#   Building wheel for fvcore (setup.py): started
#   Building wheel for fvcore (setup.py): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220512-py3-none-any.whl size=61288 sha256=75f61dfe6ee2ddeb4307829924c37714ad874acb9b83b77d91f22b7fe42335dc
#   Stored in directory: c:\users\imane\appdata\local\pip\cache\wheels\68\20\f9\a11a0dd63f4c13678b2a5ec488e48078756505c7777b75b29e
#   Building wheel for imantics (setup.py): started
#   Building wheel for imantics (setup.py): finished with status 'done'
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16031 sha256=737e692b374e667f8ca7fcb5eb52e07d5eeee42517e23aaf71d846babdb7aee8
#   Stored in directory: c:\users\imane\appdata\local\pip\cache\wheels\da\7c\3e\296fe3ed4eb3bd713e91dee0d0549f12f316d49939a64bdc96
# Successfully built fvcore imantics
# Installing collected packages: PyWavelets, scikit-image, lxml, importlib-resources, pyQt5, labelme2coco, imgaug, imantics, hydra-core, fvcore, dataclasses, pixellib
# Successfully installed PyWavelets-1.3.0 dataclasses-0.6 fvcore-0.1.5.post20220512 hydra-core-1.2.0 imantics-0.1.12 imgaug-0.4.0 importlib-resources-5.7.1 labelme2coco-0.2.1 lxml-4.9.0 pixellib-0.7.1 pyQt5-5.15.6 scikit-image-0.19.2

# %%
import pixellib

# %%
pip install tf-nightly
# Out:
# Collecting tf-nightly
#   Downloading tf_nightly-2.10.0.dev20220603-cp37-cp37m-win_amd64.whl (359.3 MB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp37-cp37m-win_amd64.whl (896 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.1.0)
# Collecting tf-estimator-nightly~=2.10.0.dev
#   Downloading tf_estimator_nightly-2.10.0.dev2022060408-py2.py3-none-any.whl (438 kB)
# Collecting tb-nightly~=2.10.0.a
#   Downloading tb_nightly-2.10.0a20220603-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.44.0)
# Collecting keras-nightly~=2.10.0.dev
#   Downloading keras_nightly-2.10.0.dev2022060407-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: packaging in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (21.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (13.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (0.24.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (0.2.0)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-win_amd64.whl (2.6 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.16.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.21.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.6.3)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (61.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (3.10.0.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\imane\anaconda3\lib\site-packages (from tf-nightly) (1.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\imane\anaconda3\lib\site-packages (from astunparse>=1.6.0->tf-nightly) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.6.5)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\imane\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (3.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\imane\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\imane\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\imane\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\imane\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\imane\anaconda3\lib\site-packages (from markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\imane\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\imane\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\imane\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\imane\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imane\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\imane\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\imane\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\imane\anaconda3\lib\site-packages (from packaging->tf-nightly) (3.0.4)
# Installing collected packages: protobuf, tf-estimator-nightly, tb-nightly, keras-nightly, h5py, gast, flatbuffers, tf-nightly
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
#   Attempting uninstall: tf-estimator-nightly
#     Found existing installation: tf-estimator-nightly 2.8.0.dev2021122109
#     Uninstalling tf-estimator-nightly-2.8.0.dev2021122109:
#       Successfully uninstalled tf-estimator-nightly-2.8.0.dev2021122109
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# Successfully installed flatbuffers-1.12 gast-0.4.0 h5py-3.7.0 keras-nightly-2.10.0.dev2022060407 protobuf-3.19.4 tb-nightly-2.10.0a20220603 tf-estimator-nightly-2.10.0.dev2022060408 tf-nightly-2.10.0.dev20220603
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, but you have tf-estimator-nightly 2.10.0.dev2022060408 which is incompatible.

# %%
from pixellib.semantic import semantic_segmentation
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.checkpoint_management has been moved to tensorflow.python.checkpoint.checkpoint_management. The old module will be deleted in version 2.9.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.python_state has been moved to tensorflow.python.trackable.python_state. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-c07b0efc1709> in <module>
# ----> 1 from pixellib.semantic import semantic_segmentation
#
# ~\anaconda3\lib\site-packages\pixellib\semantic\__init__.py in <module>
#       2 import numpy as np
#       3 from PIL import Image
# ----> 4 from .deeplab import Deeplab_xcep_pascal
#       5 from .deeplab import Deeplab_xcep_ade20k
#       6 import cv2
#
# ~\anaconda3\lib\site-packages\pixellib\semantic\deeplab.py in <module>
#      13 from tensorflow.python.keras.layers import Add
#      14 from tensorflow.python.keras.layers import Dropout
# ---> 15 from tensorflow.python.keras.layers import BatchNormalization
#      16 from tensorflow.python.keras.layers import Conv2D
#      17 from tensorflow.python.keras.layers import DepthwiseConv2D
#
# ImportError: cannot import name 'BatchNormalization' from 'tensorflow.python.keras.layers' (C:\Users\Imane\anaconda3\lib\site-packages\tensorflow\python\keras\layers\__init__.py)

# %%
from platform import python_version

# %%
print(python_version())
# Out:
# 3.9.7
